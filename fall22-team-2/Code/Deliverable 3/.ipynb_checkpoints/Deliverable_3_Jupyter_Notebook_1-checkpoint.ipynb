# %%
# Importing Libraries

import pandas as pd
import matplotlib.pyplot as plt

# %%
# Importing Rentsmart Dataset

rentsmart = pd.read_csv("Rentsmart.csv")
rentsmart.head()
# Out:
#                   date          violation_type                    description  \
# 0  2022-11-20T00:00:00  Enforcement Violations    Improper storage trash: res
# 1  2022-11-20T00:00:00  Enforcement Violations    Improper storage trash: res
# 2  2022-11-20T00:00:00  Enforcement Violations    Improper storage trash: res
# 3  2022-11-19T00:00:00  Enforcement Violations  Occupying City prop wo permit
# 4  2022-11-19T00:00:00  Enforcement Violations    Improper storage trash: res
#
#                         address  neighborhood  zip_code      parcel  \
# 0  325-327 Dorchester St, 02127  South Boston      2127   700214040
# 1          7 Aberdeen St, 02215        Boston      2215  2100139000
# 2                62 H St, 02127  South Boston      2127   603197000
# 3          9 Anderson St, 02114        Boston      2114   502218000
# 4          9 Anderson St, 02114        Boston      2114   502218000
#
#                                   owner  year built  year remodeled  \
# 0  THREE-25 -327 DORCHESTER ST CONDO TR      1928.0          2010.0
# 1              SEVEN 21 ABERDEEN STREET      1999.0          1999.0
# 2             SIXTY-2 H STREET CONDO TR      1890.0          2009.0
# 3   EMERALD REALTY CAPITAL LLC MASS LLC      1899.0          2014.0
# 4   EMERALD REALTY CAPITAL LLC MASS LLC      1899.0          2014.0
#
#                  property_type  latitude  longitude
# 0            Condominium Main*  42.33124  -71.05411
# 1            Condominium Main*  42.34642  -71.10403
# 2            Condominium Main*  42.33589  -71.04138
# 3  Residential 7 or more units  42.36076  -71.06799
# 4  Residential 7 or more units  42.36076  -71.06799

# %%
# Printing all column names of the Rentsmart dataset

rentsmart.columns
# Out:
# Index(['date', 'violation_type', 'description', 'address', 'neighborhood',
#        'zip_code', 'parcel', 'owner', 'year built', 'year remodeled',
#        'property_type', 'latitude', 'longitude'],
#       dtype='object')

# %%
# Extracting all years in which houses in Boston were built and the number of houses built each year

a = rentsmart['year built'].value_counts()

# %%
# Extracting all years from the dictionary

x = a.keys()

# %%
# Printing the total no. of years in which houses were built in Boston city

len(a)
# Out:
# 224

# %%
# Finding the total no. of houses in Boston city (according to the Rentsmart dataset)

summ = 0.0
for i in range(len(a)):
    summ+=a[x[i]]

# %%
# Printing all these years

p = list(x)
p.sort()
p
# Out:
# [1700.0,
#  1725.0,
#  1752.0,
#  1760.0,
#  1775.0,
#  1780.0,
#  1785.0,
#  1790.0,
#  1792.0,
#  1798.0,
#  1799.0,
#  1800.0,
#  1802.0,
#  1803.0,
#  1805.0,
#  1806.0,
#  1807.0,
#  1809.0,
#  1810.0,
#  1811.0,
#  1812.0,
#  1814.0,
#  1816.0,
#  1818.0,
#  1819.0,
#  1820.0,
#  1821.0,
#  1822.0,
#  1823.0,
#  1824.0,
#  1825.0,
#  1826.0,
#  1827.0,
#  1828.0,
#  1829.0,
#  1830.0,
#  1831.0,
#  1833.0,
#  1834.0,
#  1835.0,
#  1836.0,
#  1837.0,
#  1838.0,
#  1839.0,
#  1840.0,
#  1841.0,
#  1842.0,
#  1843.0,
#  1844.0,
#  1845.0,
#  1846.0,
#  1847.0,
#  1848.0,
#  1849.0,
#  1850.0,
#  1851.0,
#  1852.0,
#  1853.0,
#  1854.0,
#  1855.0,
#  1856.0,
#  1857.0,
#  1858.0,
#  1859.0,
#  1860.0,
#  1861.0,
#  1862.0,
#  1863.0,
#  1864.0,
#  1865.0,
#  1866.0,
#  1867.0,
#  1868.0,
#  1869.0,
#  1870.0,
#  1871.0,
#  1872.0,
#  1873.0,
#  1874.0,
#  1875.0,
#  1876.0,
#  1877.0,
#  1878.0,
#  1879.0,
#  1880.0,
#  1881.0,
#  1882.0,
#  1883.0,
#  1884.0,
#  1885.0,
#  1886.0,
#  1887.0,
#  1888.0,
#  1889.0,
#  1890.0,
#  1891.0,
#  1892.0,
#  1893.0,
#  1894.0,
#  1895.0,
#  1896.0,
#  1897.0,
#  1898.0,
#  1899.0,
#  1900.0,
#  1901.0,
#  1902.0,
#  1903.0,
#  1904.0,
#  1905.0,
#  1906.0,
#  1907.0,
#  1908.0,
#  1909.0,
#  1910.0,
#  1911.0,
#  1912.0,
#  1913.0,
#  1914.0,
#  1915.0,
#  1916.0,
#  1917.0,
#  1918.0,
#  1919.0,
#  1920.0,
#  1921.0,
#  1922.0,
#  1923.0,
#  1924.0,
#  1925.0,
#  1926.0,
#  1927.0,
#  1928.0,
#  1929.0,
#  1930.0,
#  1931.0,
#  1932.0,
#  1933.0,
#  1934.0,
#  1935.0,
#  1936.0,
#  1937.0,
#  1938.0,
#  1939.0,
#  1940.0,
#  1941.0,
#  1942.0,
#  1943.0,
#  1944.0,
#  1945.0,
#  1946.0,
#  1947.0,
#  1948.0,
#  1949.0,
#  1950.0,
#  1951.0,
#  1952.0,
#  1953.0,
#  1954.0,
#  1955.0,
#  1956.0,
#  1957.0,
#  1958.0,
#  1959.0,
#  1960.0,
#  1961.0,
#  1962.0,
#  1963.0,
#  1964.0,
#  1965.0,
#  1966.0,
#  1967.0,
#  1968.0,
#  1969.0,
#  1970.0,
#  1971.0,
#  1972.0,
#  1973.0,
#  1974.0,
#  1975.0,
#  1976.0,
#  1977.0,
#  1978.0,
#  1979.0,
#  1980.0,
#  1981.0,
#  1982.0,
#  1983.0,
#  1984.0,
#  1985.0,
#  1986.0,
#  1987.0,
#  1988.0,
#  1989.0,
#  1990.0,
#  1991.0,
#  1992.0,
#  1993.0,
#  1994.0,
#  1995.0,
#  1996.0,
#  1997.0,
#  1998.0,
#  1999.0,
#  2000.0,
#  2001.0,
#  2002.0,
#  2003.0,
#  2004.0,
#  2005.0,
#  2006.0,
#  2007.0,
#  2008.0,
#  2009.0,
#  2010.0,
#  2011.0,
#  2012.0,
#  2013.0,
#  2014.0,
#  2015.0,
#  2016.0,
#  2017.0,
#  2018.0,
#  2019.0]

# %%
# Finding the percentage of houses built per year in Boston city

percts = []
for i in range(len(a)):
    percts.append((a[x[i]]/summ)*100)
percts
# Out:
# [13.38881612221343,
#  11.557689564394185,
#  11.003942368793039,
#  10.253400941499915,
#  9.65491304742514,
#  9.572564225596865,
#  6.318488931540248,
#  2.119023226258251,
#  1.9251468662058588,
#  1.5536045440987667,
#  1.4790367133093851,
#  1.4608810675519706,
#  1.1460751384367989,
#  1.0711830996874636,
#  0.9029191684714243,
#  0.8704983724760411,
#  0.7122848880185707,
#  0.6549000791067423,
#  0.6241003229111282,
#  0.6156709159523285,
#  0.40785361362192163,
#  0.35922241962884677,
#  0.3300437032330018,
#  0.3164269689149408,
#  0.3105912256357718,
#  0.3070249380762796,
#  0.3021618186769721,
#  0.2901661241586803,
#  0.27654938984061933,
#  0.2512611689642204,
#  0.24348017792532842,
#  0.23569918688643643,
#  0.21365304560957582,
#  0.20619626253063766,
#  0.1987394794516995,
#  0.19160690433271518,
#  0.1870679928933615,
#  0.18512274513363852,
#  0.18415012125377703,
#  0.16437343569659324,
#  0.16177977201696256,
#  0.1601587322171934,
#  0.1601587322171934,
#  0.15594402873779356,
#  0.1533503650581629,
#  0.15302615709820908,
#  0.14200308645977874,
#  0.14005783870005575,
#  0.13713996706047127,
#  0.13487051134079445,
#  0.13227684766116377,
#  0.13000739194148694,
#  0.12871056010167162,
#  0.12871056010167162,
#  0.12838635214171779,
#  0.1267653123419486,
#  0.1264411043819948,
#  0.11412120190374914,
#  0.11282437006393381,
#  0.11023070638430314,
#  0.10731283474471864,
#  0.10698862678476483,
#  0.10601600290490332,
#  0.09726238798614983,
#  0.096938180026196,
#  0.09466872430651918,
#  0.0940203083866115,
#  0.09239926858684235,
#  0.09077822878707317,
#  0.08980560490721169,
#  0.08883298102735018,
#  0.08559090142781185,
#  0.08559090142781185,
#  0.08559090142781185,
#  0.08526669346785802,
#  0.08494248550790419,
#  0.08332144570813503,
#  0.07975515814864287,
#  0.07943095018868904,
#  0.0791067422287352,
#  0.0791067422287352,
#  0.07748570242896603,
#  0.07424362282942772,
#  0.07100154322988937,
#  0.07035312730998171,
#  0.07035312730998171,
#  0.07035312730998171,
#  0.06970471139007406,
#  0.06516579995072039,
#  0.06224792831113589,
#  0.06095109647132056,
#  0.060302680551412906,
#  0.05965426463150523,
#  0.05965426463150523,
#  0.0593300566715514,
#  0.059005848711597565,
#  0.05511535319215157,
#  0.05479114523219774,
#  0.05446693727224391,
#  0.05446693727224391,
#  0.05446693727224391,
#  0.053818521352336245,
#  0.05349431339238241,
#  0.05219748155256708,
#  0.051549065632659416,
#  0.050576441752797914,
#  0.05025223379284408,
#  0.04992802583289025,
#  0.04992802583289025,
#  0.04960381787293642,
#  0.04927960991298259,
#  0.04733436215325959,
#  0.04571332235349042,
#  0.04571332235349042,
#  0.04474069847362892,
#  0.04441649051367509,
#  0.04311965867385976,
#  0.042795450713905926,
#  0.039877579074321434,
#  0.036635499474783104,
#  0.034690251715060114,
#  0.034366043755106275,
#  0.03339341987524477,
#  0.03144817211552178,
#  0.030799756195614113,
#  0.029827132315752614,
#  0.029502924355798783,
#  0.02917871639584495,
#  0.02917871639584495,
#  0.028530300475937284,
#  0.028206092515983452,
#  0.027557676596075786,
#  0.026585052716214287,
#  0.026260844756260456,
#  0.026260844756260456,
#  0.025936636796306624,
#  0.025288220876398957,
#  0.024964012916445125,
#  0.024639804956491294,
#  0.02431559699653746,
#  0.02431559699653746,
#  0.023991389036583627,
#  0.02204614127686063,
#  0.021397725356952963,
#  0.0207493094370453,
#  0.0207493094370453,
#  0.0197766855571838,
#  0.019128269637276134,
#  0.0178314377974608,
#  0.01750722983750697,
#  0.017183021877553138,
#  0.016858813917599306,
#  0.01653460595764547,
#  0.015561982077783972,
#  0.015561982077783972,
#  0.01523777411783014,
#  0.014913566157876307,
#  0.014913566157876307,
#  0.014265150237968642,
#  0.01394094227801481,
#  0.013292526358107144,
#  0.011995694518291813,
#  0.011023070638430315,
#  0.01037465471852265,
#  0.009726238798614983,
#  0.009726238798614983,
#  0.009726238798614983,
#  0.00810519899884582,
#  0.007132575118984321,
#  0.007132575118984321,
#  0.006484159199076656,
#  0.006484159199076656,
#  0.006484159199076656,
#  0.00583574327916899,
#  0.005187327359261325,
#  0.0048631193993074915,
#  0.0048631193993074915,
#  0.0048631193993074915,
#  0.0048631193993074915,
#  0.0048631193993074915,
#  0.0042147034793998265,
#  0.0042147034793998265,
#  0.003890495519445993,
#  0.0035662875594921605,
#  0.0035662875594921605,
#  0.0035662875594921605,
#  0.0035662875594921605,
#  0.002917871639584495,
#  0.002917871639584495,
#  0.002917871639584495,
#  0.002917871639584495,
#  0.002917871639584495,
#  0.0025936636796306625,
#  0.0022694557196768295,
#  0.0022694557196768295,
#  0.0022694557196768295,
#  0.0019452477597229965,
#  0.0019452477597229965,
#  0.001621039799769164,
#  0.0012968318398153312,
#  0.0012968318398153312,
#  0.0012968318398153312,
#  0.0009726238798614983,
#  0.0009726238798614983,
#  0.0009726238798614983,
#  0.0009726238798614983,
#  0.0009726238798614983,
#  0.0006484159199076656,
#  0.0006484159199076656,
#  0.0006484159199076656,
#  0.0006484159199076656,
#  0.0006484159199076656,
#  0.0006484159199076656,
#  0.0006484159199076656,
#  0.0006484159199076656,
#  0.0006484159199076656,
#  0.0003242079599538328,
#  0.0003242079599538328,
#  0.0003242079599538328,
#  0.0003242079599538328,
#  0.0003242079599538328,
#  0.0003242079599538328,
#  0.0003242079599538328,
#  0.0003242079599538328]

# %%
# Extracting the 20 years with the highest percentage of houses built along with their percentages

x = x[:20]
percts = percts[:20]

# %%
# Converting x to a list

x = list(x)

# %%
# Converting the int/float values (years) of x into string

for i in range(len(x)):
    x[i] = str(int(x[i]))
x[0]
# Out:
# '1900'

# %%
# Plotting a bar graph for the 20 years when the most percentages of houses were built in Boston city

plt.xticks(rotation = 90)
plt.title("Percentage of Violations vs Year Built")
plt.xlabel("Year Built")
plt.ylabel("Percentage of Violations")
plt.bar(x, percts)
# Out:
# <BarContainer object of 20 artists>

# %%
# Extracting all years in which houses in Boston were remodelled and the number of houses remodelled each year

a = rentsmart['year remodeled'].value_counts()

# %%
# Extracting all years from the dictionary

x = a.keys()

# %%
# Printing all these years

p = list(x)
p.sort()
p
# Out:
# [0.0,
#  1900.0,
#  1902.0,
#  1910.0,
#  1919.0,
#  1920.0,
#  1923.0,
#  1925.0,
#  1930.0,
#  1933.0,
#  1934.0,
#  1935.0,
#  1940.0,
#  1941.0,
#  1942.0,
#  1945.0,
#  1946.0,
#  1947.0,
#  1948.0,
#  1949.0,
#  1950.0,
#  1951.0,
#  1952.0,
#  1953.0,
#  1955.0,
#  1956.0,
#  1957.0,
#  1958.0,
#  1959.0,
#  1960.0,
#  1961.0,
#  1962.0,
#  1963.0,
#  1964.0,
#  1965.0,
#  1966.0,
#  1967.0,
#  1968.0,
#  1969.0,
#  1970.0,
#  1971.0,
#  1972.0,
#  1973.0,
#  1974.0,
#  1975.0,
#  1976.0,
#  1977.0,
#  1978.0,
#  1979.0,
#  1980.0,
#  1981.0,
#  1982.0,
#  1983.0,
#  1984.0,
#  1985.0,
#  1986.0,
#  1987.0,
#  1988.0,
#  1989.0,
#  1990.0,
#  1991.0,
#  1992.0,
#  1993.0,
#  1994.0,
#  1995.0,
#  1996.0,
#  1997.0,
#  1998.0,
#  1999.0,
#  2000.0,
#  2001.0,
#  2002.0,
#  2003.0,
#  2004.0,
#  2005.0,
#  2006.0,
#  2007.0,
#  2008.0,
#  2009.0,
#  2010.0,
#  2011.0,
#  2012.0,
#  2013.0,
#  2014.0,
#  2015.0,
#  2016.0,
#  2017.0,
#  2018.0,
#  2019.0]

# %%
# Finding the total no. of houses in Boston city (according to the Rentsmart dataset)

summ = 0.0
for i in range(len(a)):
    summ+=a[x[i]]
summ
# Out:
# 202474.0

# %%
# Finding the percentage of houses remodeled per year in Boston city

percts = []
for i in range(len(a)):
    percts.append((a[x[i]]/summ)*100)
percts
# Out:
# [15.611387141065025,
#  5.538488892400999,
#  5.433290200223238,
#  5.4273635133399845,
#  4.793701907405396,
#  4.004464770785384,
#  3.1515157501703923,
#  2.9984096723529934,
#  2.7499827138299238,
#  2.725288185149698,
#  2.6250283987079825,
#  2.539091438900797,
#  2.4729101020377926,
#  2.3716625344488675,
#  2.3519069115046873,
#  2.3044934164386537,
#  2.295603386113773,
#  2.141509527149165,
#  1.9982812608038563,
#  1.923703784189575,
#  1.7947983444787974,
#  1.7498543022807864,
#  1.6268755494532634,
#  1.6244060965852407,
#  1.476238924503887,
#  1.4708061281942373,
#  1.3749913569149619,
#  1.2174402639351225,
#  1.182374033209202,
#  1.0969309639756215,
#  0.8480101148789474,
#  0.8139316653002361,
#  0.7413297509803728,
#  0.72898248664026,
#  0.7200924563153788,
#  0.6800873198534132,
#  0.5724191748076296,
#  0.5585902387467032,
#  0.52648735146241,
#  0.5057439473710205,
#  0.4627754674674279,
#  0.43166036133034363,
#  0.3975819117516323,
#  0.3333761371830457,
#  0.263243675731205,
#  0.22916522615249366,
#  0.16100832699507098,
#  0.1540938589646078,
#  0.11754595651787392,
#  0.10569258275136562,
#  0.10371702045694756,
#  0.06173632170056403,
#  0.06124243112695951,
#  0.053834072522891824,
#  0.043462370477197074,
#  0.039511245888360975,
#  0.02469452868022561,
#  0.022225075812203048,
#  0.01827395122336695,
#  0.015310607781739878,
#  0.013335045487321829,
#  0.012841154913717318,
#  0.012347264340112804,
#  0.011853373766508291,
#  0.009877811472090244,
#  0.00889003032488122,
#  0.006914468030463171,
#  0.006420577456858659,
#  0.006420577456858659,
#  0.005926686883254146,
#  0.004938905736045122,
#  0.004938905736045122,
#  0.00444501516244061,
#  0.003951124588836097,
#  0.002469452868022561,
#  0.0019755622944180487,
#  0.0019755622944180487,
#  0.0019755622944180487,
#  0.0014816717208135364,
#  0.0014816717208135364,
#  0.0014816717208135364,
#  0.0014816717208135364,
#  0.0009877811472090243,
#  0.0004938905736045122,
#  0.0004938905736045122,
#  0.0004938905736045122,
#  0.0004938905736045122,
#  0.0004938905736045122,
#  0.0004938905736045122]

# %%
# Extracting the 20 years with the highest percentage of houses remodeled along with their percentages

x = x[:20]
percts = percts[:20]

# %%
# Converting x to a list

x = list(x)

# %%
# Plotting a bar graph for the 20 years when the most percentages of houses were remodelled in Boston city

plt.xlabel("Year Built")
plt.ylabel("Number of Violations")
plt.title("Number of Violations based on Year Built")
rentsmart['year built'].value_counts().nlargest(15).plot(kind="bar")
# Out:
# <AxesSubplot:title={'center':'Number of Violations based on Year Built'}, xlabel='Year Built', ylabel='Number of Violations'>

# %%
# Plotting the 15 years which had the highest number of violations (years remodelled)

plt.xlabel("Year Remodeled")
plt.ylabel("Number of Violations")
plt.title("Number of Violations based on Year Remodeled")
rentsmart['year remodeled'].value_counts().nlargest(15).plot(kind="barh")
# Out:
# <AxesSubplot:title={'center':'Number of Violations based on Year Remodeled'}, xlabel='Year Remodeled', ylabel='Number of Violations'>

# %%
# Importing the 311 Service Requests Dataset

service_reqs = pd.read_csv("311 Service Requests.csv")
service_reqs.head()
# Out:
#    case_enquiry_id              open_dt            target_dt  \
# 0     101004143507  2022-01-22 08:14:00  2022-01-25 08:30:00
# 1     101004232225  2022-03-24 12:36:00  2022-04-14 12:36:52
# 2     101004194256  2022-02-18 16:48:00  2023-02-18 16:48:41
# 3     101004202046  2022-02-26 14:30:00  2022-03-01 08:30:00
# 4     101004151776  2022-01-30 11:17:00                  NaN
#
#              closed_dt   ontime case_status                closure_reason  \
# 0                  NaN  OVERDUE        Open
# 1  2022-03-24 12:37:41   ONTIME      Closed  Case Closed Case Invalid
# 2                  NaN   ONTIME        Open
# 3                  NaN  OVERDUE        Open
# 4  2022-01-30 11:31:43   ONTIME      Closed    Case Closed Case Noted
#
#                           case_title                            subject  \
# 0                            Pothole            Public Works Department
# 1         Request for Recycling Cart            Public Works Department
# 2  Boston Bikes: Bike Racks; Request  Transportation - Traffic Division
# 3         Request for Pothole Repair            Public Works Department
# 4            PublicWorks: Compliment            Mayor's 24 Hour Hotline
#
#                         reason  ... police_district        neighborhood  \
# 0          Highway Maintenance  ...              B2             Roxbury
# 1                    Recycling  ...              B3          Dorchester
# 2                 Boston Bikes  ...             D14              Boston
# 3          Highway Maintenance  ...             D14  Allston / Brighton
# 4  Employee & General Comments  ...              E5        West Roxbury
#
#   neighborhood_services_district     ward precinct  \
# 0                             13        9     0904
# 1                              7  Ward 17     1714
# 2                             14       21     2102
# 3                             15  Ward 22     2212
# 4                             12  Ward 20     2016
#
#                        location_street_name location_zipcode latitude  \
# 0  INTERSECTION Elmwood St & Malcolm X Blvd              NaN  42.3594
# 1                            87-89 River St           2126.0  42.2715
# 2                      915 Commonwealth Ave           2215.0  42.3518
# 3                          2-8 Arlington St           2135.0  42.3516
# 4                             7 Earnshaw St           2132.0  42.2745
#
#   longitude                source
# 0  -71.0587       City Worker App
# 1  -71.0744    Employee Generated
# 2  -71.1168      Constituent Call
# 3  -71.1523  Citizens Connect App
# 4  -71.1638      Constituent Call
#
# [5 rows x 29 columns]

# %%
# Printing the column names in the 311 Service Requests Dataset

service_reqs.columns
# Out:
# Index(['case_enquiry_id', 'open_dt', 'target_dt', 'closed_dt', 'ontime',
#        'case_status', 'closure_reason', 'case_title', 'subject', 'reason',
#        'type', 'queue', 'department', 'submittedphoto', 'closedphoto',
#        'location', 'fire_district', 'pwd_district', 'city_council_district',
#        'police_district', 'neighborhood', 'neighborhood_services_district',
#        'ward', 'precinct', 'location_street_name', 'location_zipcode',
#        'latitude', 'longitude', 'source'],
#       dtype='object')

# %%
# Importing the Building and Property Violations Dataset

bp_violations = pd.read_csv("Building and Property Violations.csv")
bp_violations.head()
# Out:
#         case_no          status_dttm status          code  value  \
# 0  HVIOL-644882  2022-11-18 09:50:19   Open  CMR410.550 B    NaN
# 1  HVIOL-644882  2022-11-18 09:50:19   Open  CMR410.482 A    NaN
# 2  HVIOL-644882  2022-11-18 09:50:19   Open  CMR410.482 A    NaN
# 3  HVIOL-644882  2022-11-18 09:50:19   Open  CRM410.550 D    NaN
# 4  HVIOL-644882  2022-11-18 09:50:19   Open  CMR410.550 B    NaN
#
#                                          description violation_stno  \
# 0  Extermination of Insects, Rodents and Skunks -...             19
# 1  Smoke Detectors & Carbon Monoxide Alarms - Own...             19
# 2  Smoke Detectors & Carbon Monoxide Alarms - Own...             19
# 3  Extermination of Insects, Rodents and Skunks -...             19
# 4  Extermination of Insects, Rodents and Skunks -...             19
#
#   violation_sthigh violation_street violation_suffix  ... ward  \
# 0              NaN            Adams               ST  ...   15
# 1              NaN            Adams               ST  ...   15
# 2              NaN            Adams               ST  ...   15
# 3              NaN            Adams               ST  ...   15
# 4              NaN            Adams               ST  ...   15
#
#       contact_addr1 contact_addr2 contact_city contact_state contact_zip  \
# 0  77 Pond Ave #401           NaN    Brookline            MA       02445
# 1  77 Pond Ave #401           NaN    Brookline            MA       02445
# 2  77 Pond Ave #401           NaN    Brookline            MA       02445
# 3  77 Pond Ave #401           NaN    Brookline            MA       02445
# 4  77 Pond Ave #401           NaN    Brookline            MA       02445
#
#    sam_id latitude longitude                                 location
# 0  175531  42.3076  -71.0634  (42.30760000002404, -71.06340000126664)
# 1  175531  42.3076  -71.0634  (42.30760000002404, -71.06340000126664)
# 2  175531  42.3076  -71.0634  (42.30760000002404, -71.06340000126664)
# 3  175531  42.3076  -71.0634  (42.30760000002404, -71.06340000126664)
# 4  175531  42.3076  -71.0634  (42.30760000002404, -71.06340000126664)
#
# [5 rows x 23 columns]

# %%
# Printing the column names in the Building and Property Violations Dataset

bp_violations.columns
# Out:
# Index(['case_no', 'status_dttm', 'status', 'code', 'value', 'description',
#        'violation_stno', 'violation_sthigh', 'violation_street',
#        'violation_suffix', 'violation_city', 'violation_state',
#        'violation_zip', 'ward', 'contact_addr1', 'contact_addr2',
#        'contact_city', 'contact_state', 'contact_zip', 'sam_id', 'latitude',
#        'longitude', 'location'],
#       dtype='object')
