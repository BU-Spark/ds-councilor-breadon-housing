# %%
import warnings
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

#ignore by message
warnings.filterwarnings("ignore")

import pandas as pd

df = pd.read_csv("zillow.csv", low_memory=False)
df.head()
# Out:
#    RegionID  SizeRank   RegionName RegionType StateName State  \
# 0      6181         0     New York       city        NY    NY
# 1     12447         1  Los Angeles       city        CA    CA
# 2     39051         2      Houston       city        TX    TX
# 3     17426         3      Chicago       city        IL    IL
# 4      6915         4  San Antonio       city        TX    TX
#
#                                    Metro          CountyName  2000-01-31  \
# 0  New York-Newark-Jersey City, NY-NJ-PA       Queens County    253690.0
# 1     Los Angeles-Long Beach-Anaheim, CA  Los Angeles County    234181.0
# 2   Houston-The Woodlands-Sugar Land, TX       Harris County    109068.0
# 3     Chicago-Naperville-Elgin, IL-IN-WI         Cook County    166139.0
# 4          San Antonio-New Braunfels, TX        Bexar County    114794.0
#
#    2000-02-29  ...  2021-12-31  2022-01-31  2022-02-28  2022-03-31  \
# 0    255517.0  ...    741586.0    745686.0    750578.0    756734.0
# ...

# %%
df = df.loc[(df['RegionName'] == "Boston")]
df.head()
# Out:
#        RegionID  SizeRank RegionName RegionType StateName State  \
# 26        44269        26     Boston       city        MA    MA
# 9660      23778     10293     Boston       city        GA    GA
# 11747    146577     12655     Boston       city        KY    KY
# 13281    395421     14526     Boston       city        VA    VA
#
#                                               Metro       CountyName  \
# 26                   Boston-Cambridge-Newton, MA-NH   Suffolk County
# 9660                                Thomasville, GA    Thomas County
# 11747                                 Bardstown, KY    Nelson County
# 13281  Washington-Arlington-Alexandria, DC-VA-MD-WV  Culpeper County
#
#        2000-01-31  2000-02-29  ...  2021-12-31  2022-01-31  2022-02-28  \
# 26       220359.0    221907.0  ...    689240.0    695919.0    703758.0
# 9660      98732.0     99526.0  ...    173678.0    177292.0    182589.0
# 11747     89129.0     88752.0  ...    209842.0    213638.0    215155.0
# ...

# %%
a = list(df.columns)
a
# df.plot(x="RegionName", y=["2000-01-31", "2000-02-29", '2000-03-31',
#  '2000-04-30',
#  '2000-05-31',
#  '2000-06-30',
#  '2000-07-31',
#  '2000-08-31',
#  '2000-09-30',
#  '2000-10-31',
#  '2000-11-30',
#  '2000-12-31',
#  '2001-01-31',
#  '2001-02-28',
#  '2001-03-31',
#  '2001-04-30',
#  '2001-05-31'], kind="line", figsize=(10, 9))
X_axis = np.arange(len(a))

df.plot(x="RegionID", y="2000-01-31", kind="bar", figsize=(10, 9))
plt.bar(X_axis, df["2000-01-31"], label = 'Girls')
plt.bar(X_axis, df["2000-02-29"], label = 'Boys')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [10], line 21
#      18 X_axis = np.arange(len(a))
#      20 df.plot(x="RegionID", y="2000-01-31", kind="bar", figsize=(10, 9))
# ---> 21 plt.bar(X_axis, df["2000-01-31"], label = 'Girls')
#      22 plt.bar(X_axis, df["2000-02-29"], label = 'Boys')
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/pyplot.py:2357, in bar(x, height, width, bottom, align, data, **kwargs)
#    2353 @_copy_docstring_and_deprecators(Axes.bar)
#    2354 def bar(
#    2355         x, height, width=0.8, bottom=None, *, align='center',
#    2356         data=None, **kwargs):
# -> 2357     return gca().bar(
#    2358         x, height, width=width, bottom=bottom, align=align,
#    2359         **({"data": data} if data is not None else {}), **kwargs)
#
# ...
