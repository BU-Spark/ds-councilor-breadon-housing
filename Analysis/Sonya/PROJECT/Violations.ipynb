# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
import numpy as np 

sns.set()

# %%
df = pd.read_csv("/Users/sv/Desktop/BU/SENIORYEAR/CS 506/PROJECT/Code_Reinforcement_Violations.csv", low_memory=False)
# df
v_df = df[['violation_suffix', 'violation_zip']].copy()
v_df['count_suffix'] = df['violation_suffix'].map(df['violation_suffix'].value_counts())
df['violation_suffix'].value_counts().to_csv('suffix_counts', index=False)
print(df['violation_suffix'].value_counts())
violations_plot = sns.barplot(data= v_df,  x= 'violation_suffix', y= 'count_suffix')
plt.xticks(rotation=90)
plt.xticks(v_df['violation_suffix'][::50])
plt.show()
# Out:
# ST      444571
# AVE      85831
# RD       36020
# St        6214
# PL        4233
# TER       3618
# SQ        3535
# PARK      3092
# CT        2144
# HWY       2052
# DR        1833
# AV        1639
# WAY       1273
# Av         929
# PKWY       736
# BLVD       723
# CIR        387
# LN         298
#            283
# Pz         235
# CIRT       158
# PLZ        151
# GRN        129
# Pw         113
# HW         112
# Rd          90
# Wy          55
# ROW         41
# PW          41
# PK          35
# Pl          26
# Ct          25
# TE          23
# WY          18
# AL          17
# Pk          16
# WHF         14
# CI          12
# Hw          11
# Te           5
# Dr           5
# Sq           4
# WH           4
# PZ           3
# MALL         2
# CRES         2
# Bl           2
# ALY          1
# BL           1
# GDNS         1
# Ci           1
# Name: violation_suffix, dtype: int64
# ---------------------------------------------------------------------------
# ...
