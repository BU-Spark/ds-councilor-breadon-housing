# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
rentsmart = pd.read_csv('rentsmart.csv')

# %%
rentsmart.head(100)
# Out:
#                    date          violation_type  \
# 0   2022-10-16 00:00:00  Enforcement Violations
# 1   2022-10-16 00:00:00  Enforcement Violations
# 2   2022-10-15 00:00:00  Enforcement Violations
# 3   2022-10-15 00:00:00  Enforcement Violations
# 4   2022-10-15 00:00:00  Enforcement Violations
# ..                  ...                     ...
# 95  2022-10-15 00:00:00  Enforcement Violations
# 96  2022-10-15 00:00:00  Enforcement Violations
# 97  2022-10-15 00:00:00  Enforcement Violations
# 98  2022-10-15 00:00:00  Enforcement Violations
# 99  2022-10-15 00:00:00  Enforcement Violations
#
#                        description                         address  \
# 0      Improper storage trash: res          57 Clarendon St, 02116
# 1   Overfilling of barrel/dumpster             14 Marion St, 02128
# 2      Improper storage trash: res  2969-2975 Washington St, 02119
# 3      Improper storage trash: res          15 S Russell St, 02114
# 4      Improper storage trash: res          423 Shawmut Ave, 02118
# ..                             ...                             ...
# 95     Improper storage trash: res             60 Falcon St, 02128
# 96     Improper storage trash: res         12B Greenwood St, 02121
# 97     Improper storage trash: res      76 Commonwealth Ave, 02116
# 98     Improper storage trash: res                 233 E St, 02127
# 99     Improper storage trash: res           3 McCormick Sq, 02128
#
#     neighborhood  zip_code      parcel                                  owner  \
# 0         Boston      2116   501066000    CLARENDON PROPERTIES LLC A MASS LLC
# 1    East Boston      2128   102734000                    URBAN RENEWAL X LLC
# 2        Roxbury      2119  1100962000                    2969 WASHINGTON LLC
# 3         Boston      2114   300196000                     DANIELS MARK JASON
# 4        Roxbury      2118   900324000          SARA REAL ESTATE LLC MASS LLC
# ..           ...       ...         ...                                    ...
# 95   East Boston      2128   103533000                         KEHOE THOMAS J
# 96    Dorchester      2121  1401659000                          VU REALTY LLC
# 97        Boston      2116   501266010  SEVENTY 4-76 COMMONWEALTH AV CONDO TR
# 98  South Boston      2127   600933000                  RAZWAD FRANCES M ETAL
# 99   East Boston      2128   104686000                SOLSKINN PROPERTIES LLC
#
#     year built  year remodeled                 property_type   latitude  \
# 0       1899.0          1996.0   Residential 7 or more units  42.346710
# 1       1910.0          1979.0   Residential 7 or more units  42.380420
# 2       1920.0          2014.0   Residential 7 or more units  42.317960
# 3       1870.0          2016.0          Residential 1-family  42.360690
# 4       1905.0          2004.0   Residential 7 or more units  42.340130
# ..         ...             ...                           ...        ...
# 95      1900.0          2002.0          Residential 3-family  42.382139
# 96      2007.0             NaN   Residential 7 or more units  42.301918
# 97      1900.0          2007.0             Condominium Main*  42.352250
# 98      1890.0          2002.0          Residential 3-family  42.335410
# 99      1930.0          1990.0  Residential 4 or more family  42.364836
#
#     longitude
# 0  -71.073020
# 1  -71.038680
# 2  -71.096400
# 3  -71.066110
# 4  -71.074290
# ..        ...
# 95 -71.037234
# 96 -71.079304
# 97 -71.075160
# 98 -71.051850
# 99 -71.030969
#
# [100 rows x 13 columns]

# %%
#print(rentsmart.description.value_counts())

for element in rentsmart.description.value_counts().keys():
    print(element)
# Out:
# Improper storage trash: res
# Overfilling of barrel/dumpster
# Abandoned Vehicles
# Overgrown Weeds On Property
# Rodent Activity
# Failure clear sidewalk - snow
# Unsatisfactory Living Conditions
# Work w/out Permit
# Illegal dumping < 1 cubic yd
# Contractors Complaint
# Improper storage trash: com
# Pest Infestation - Residential
# Heat - Excessive, Insufficient
# Building Inspection Request
# Empty Litter Basket
# Unsafe Dangerous Conditions
# Abandoned Bicycle
# Working Beyond Hours
# Occupying City prop wo permit
# Contractor Complaints
# Electrical
# Protection of Adjoining Property
# Mice Infestation - Residential
# illegal parking prop owner 1
# Catchbasin
# Maintenance - Homeowner
# Unregistered motor vehicles- 2
# Maintenance Complaint - Residential
# Exceeding Terms of Permit
# Failure to Obtain Permit
# Chronic Dampness/Mold
# Illegal Occupancy
# Cross Metering - Sub-Metering
# illegal parking prop owner 2
# Failure To Register
# Maint a dumpster wopermit
# Overflowing or Un-kept Dumpster
# Illegal Rooming House
# Unsafe and Dangerous
# Unsatisfactory Utilities - Electrical, Plumbing
# Unregistered motor vehicles-1
# No Utilities Residential - Water
# Egress
# Roadway Repair
# Extermination of Insects, Rodents and Skunks - The owner of a rooming house shall maintain it and its premises free from all rodent, cockroaches, and insect infestation and shall be responsible for exterminating them
# Bed Bugs
# Utility Casting Repair
# Abandoned Building
# Maintenance
# Trash on Vacant Lot
# Testing & Certification
# Rental Unit Delivery Conditions
# Trash illegally dump container
# Removal snow private prop
# Plumbing
# No Utilities Residential - Electricity
# Carbon Monoxide
# Sewage/Septic Back-Up
# Squalid Living Conditions
# Short Term Rental
# Site Cleanliness license – WAR
# Overcrowding
# Failure clear sidewalk - snow:
# Unsafe Structures
# Litter Basket Maintenance
# Rooftop & Mechanical Disturbances
# Failure to Obtain Inspection
# Zoning
# Failed to comply w permit term
# Illegal dumping 1-5 cubic yd.:
# Mechanical
# No Utilities Residential - Gas
# No Number On A Building
# Poor Ventilation
# Failed Multiple Rental Insp
# Shopping Cart - 1
# Lead
# Failure to secure a Re-Inspect
# Extermination of Insects, Rodents and Skunks - Extermination shall be accomplished by eliminating the harborage places of insects and rodents.  All use of pesticides shall be in accordance with applicable laws and regulations of the Department of Food and Agricultures Pesticide Board.
# Failure clean sidewalk com
# Breathe Easy
# Right of Entry
# Mosquitoes (West Nile)
# Removal snow private property
# Protection of Adj. Property
# Graffiti on building- 1
# Rat Bite
# Occupying W/Out A Valid CO/CI
# Removal snow non-res property
# Non-Emergency Auto Repair
# Pigeon Infestation
# Certificate of Occupancy
# Maintenance of Means of Egress
# Building or Use of Premise req
# Site Cleanliness license – VIO
# Posting signs wo authority
# Inspections
# Utility Call-In
# Transporting refuse without pe
# Suspension or Revocation
# Shopping Cart - 2
# Acts 1956 as Amended
# Fire Protection Systems
# Failure to secure permit
# Means of Egress
# Emergency Escape & Rescue
# No use of premises permit:
# Periodic Inspections
# Student Overcrowding
# Reg. of Construction Hour
# Unlawful Continuance
# Locks and Latches
# Number of Exits or Exit Access
# Failure of Delivery Standards
# Emergency escape and rescue
# Illegal Use
# Unsafe Structure
# Illegal Vending
# Validity of Permit
# Fail to post management comp
# National Fuel Gas Code
# Municipal Bylaws or Ordinances
# Exhaust Installation
# Building
# Requirements.
# disposal med waste
# Extermination of Insects, Rodents and Skunks - Occupant of a dwelling containing one dwelling unit shall maintain it and its premises free from all rodents, cockroaches and insect infestation and shall be responsible for exterminating them
# Minimum Number of Exits
# Fire Separation
# Illegal dumping w a vehicle
# Fire Blocking Required
# Permits
# Egress Doors
# Required Inspections
# Graffiti on building- 2
# Accessible Means of Egress
# Unsafe Building & Structures
# Protection of Pedestrians
# Guarding of Live parts
# News Boxes
# Modification fire protection
# Uses not Permitted
# Handrails
# Emergency Disconnects
# Electrical Work w/out a Permit
# Emergency Openings
# Working Space
# Corridor Continuity
# Deteriorating Agents
# Access to Public Way
# Exits Maintained
# Inspection of exterior walls.
# Notice of Violation
# Elec work w/o per
# Covers & Canopies
# Large building recycling- 1
# Window Wells
# Street Numbers
# Construction Documents
# Fire and Smoke Protection
# AFCI
# Int. Exit  Stairways & Ramps
# Installation; 2015
# Unsafe Maintanence
# Electrical Connections
# I.S.S.U
# Required Plumbing Fixtures
# Clothes Dryer Exhaust
# Minimum Requirements
# Operational Constraints
# Emergency Escape
# Foyer & Lobbies
# Groups R-1, R-2, R-3 & R-4
# Footing & Foundation Insp.
# Dwelling Units & Sleeping
# Failure to call for req Insp.
# Fire Extinguishers
# Failure to Secure Permit
# Excessive Use of Ext. Cords
# Fire Alarm and Detection
# Support Wires
# Reg. of Construction Hours
# Specialized codes
# Referenced Codes & Standards
# Dangerous Structures/Premises
# Placement of Backfill
# Egress through intervening spaces
# Reg. Access to Roof Areas
# Termination
# Projections
# Address Identification
# Two exits or exit access doorways.
# Permits to perform gas fitting
# Stop Work Order
# Exhaust Openings
# Owners Installation/Maintenance Responsibility - All Owner-installed optional equipment
# Owners Responsibility to Maintain Structural Elements - Structural elements  shall be maintained free from holes, cracks, loose plaster, or other defects.
# Smoke Detectors & Carbon Monoxide Alarms - Owner shall provide, install and maintain in operable condition smoke detectors and carbon monoxide alarms
# Illegal dumping 5+ cubic yd
# Extermination of Insects, Rodents and Skunks - The owner of a dwelling containing two or more dwelling units shall maintain it and its premises free from all rodents, cockroaches and insect infestation and shall be responsible for exterminating them
# Failure to call Inspections
# Unsafe Conditions
# General - Stairways
# Basic Principles
# Adjacent to Excavations
# Work without permit
# Large building recycling - 2
# Egress thru Intervening Spaces
# Illegal dumping park
# Construction Safe Guards
# Certificate of Inspection
# Mechanical Execution of Work
# Illegal dumping: Haz Waste
# Proper Maintenance

# %%
rentsmart.neighborhood.value_counts()[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14152\240688308.py in <module>
# ----> 1 rentsmart.neighborhood.value_counts()[0].key()
#
# AttributeError: 'numpy.int64' object has no attribute 'key'

# %%
df = rentsmart

# %%
df["owner"].value_counts()
# Out:
# GBM PORTFOLIO OWNER LLC     2160
# BOBSON RESIDENTIAL LLC       479
# CESCO LLC MASS LLC           453
# TS LAND TRUST LLC            447
# COPLEY CONDOMINIUM TRUST     396
#                             ...
# DENNY REGINALD L               1
# TRAN TUNG                      1
# SHAFFER GLENN ETAL             1
# FAURNIER-FALING MICHELE        1
# DOUGLAS MARK A                 1
# Name: owner, Length: 44913, dtype: int64

# %%
df.violation_type.value_counts()
# Out:
# Enforcement Violations        206250
# Housing Complaints             54283
# Sanitation Requests            38674
# Civic Maintenance Requests      4930
# Building Violations             3271
# Housing Violations               634
# Name: violation_type, dtype: int64

# %%
top_10_owners = list(df.owner.value_counts().keys())[:10]
top_10_owners_counts = list(df.owner.value_counts().values[:10])

# %%
top_10_owners_counts
# Out:
# [2160, 479, 453, 447, 396, 374, 361, 354, 353, 335]

# %%
owners = df[df["owner"] == top_10_owners[9]]
owners["violation_type"].value_counts()
# Out:
# Enforcement Violations        253
# Housing Complaints             43
# Sanitation Requests            37
# Building Violations             1
# Civic Maintenance Requests      1
# Name: violation_type, dtype: int64

# %%
top_10_owners
# Out:
# ['GBM PORTFOLIO OWNER LLC',
#  'BOBSON RESIDENTIAL LLC',
#  'CESCO LLC MASS LLC',
#  'TS LAND TRUST LLC',
#  'COPLEY CONDOMINIUM TRUST',
#  'JPNDC  PITTS  LLC',
#  'SOLSKINN PROPERTIES LLC',
#  'LACONCHA LIMITED PARTNERSHIP',
#  'ROIFF PAUL G TS',
#  'CUONG VU']

# %%
violations311 = pd.read_csv('311violations.csv')

# %%
violations311.columns
# Out:
# Index(['case_enquiry_id', 'open_dt', 'target_dt', 'closed_dt', 'ontime',
#        'case_status', 'closure_reason', 'case_title', 'subject', 'reason',
#        'type', 'queue', 'department', 'submittedphoto', 'closedphoto',
#        'location', 'fire_district', 'pwd_district', 'city_council_district',
#        'police_district', 'neighborhood', 'neighborhood_services_district',
#        'ward', 'precinct', 'location_street_name', 'location_zipcode',
#        'latitude', 'longitude', 'source'],
#       dtype='object')

# %%
df = violations311
violations311.head()
# Out:
#    case_enquiry_id              open_dt            target_dt  \
# 0     101004124382  2022-01-12 16:47:40  2022-01-13 16:47:45
# 1     101004143743  2022-01-22 12:49:00                  NaN
# 2     101004125584  2022-01-13 19:16:33                  NaN
# 3     101004113668  2022-01-01 18:28:00  2022-01-17 08:30:00
# 4     101004113407  2022-01-01 09:47:00                  NaN
#
#              closed_dt   ontime case_status  \
# 0  2022-01-12 17:08:19   ONTIME      Closed
# 1                  NaN   ONTIME        Open
# 2  2022-01-20 16:30:29   ONTIME      Closed
# 3  2022-02-12 00:42:39  OVERDUE      Closed
# 4  2022-01-01 12:02:05   ONTIME      Closed
#
#                                       closure_reason  \
# 0  Case Closed. Closed date : Wed Jan 12 17:08:19...
# 1
# 2  Case Closed. Closed date : 2022-01-20 16:30:29...
# 3  Case Closed. Closed date : Sat Feb 12 00:42:39...
# 4  Case Closed. Closed date : Sat Jan 01 12:02:05...
#
#                                case_title                  subject  \
# 0                           CE Collection  Public Works Department
# 1                            Space Savers  Public Works Department
# 2               Schedule Bulk Item Pickup  Public Works Department
# 3  PRINTED : Street Light Outages 3rd- EP  Public Works Department
# 4                           Needle Pickup  Mayor's 24 Hour Hotline
#
#             reason  ... police_district  \
# 0  Street Cleaning  ...              A1
# 1       Sanitation  ...              B2
# 2       Sanitation  ...              C6
# 3    Street Lights  ...              A1
# 4   Needle Program  ...              C6
#
#                              neighborhood neighborhood_services_district  \
# 0                             Beacon Hill                              3
# 1                              Dorchester                             13
# 2                                  Boston                              5
# 3           Downtown / Financial District                              3
# 4  South Boston / South Boston Waterfront                              5
#
#      ward precinct                      location_street_name location_zipcode  \
# 0  Ward 3     0306                           21-23 Temple St           2114.0
# 1      12     1207                           4-6 Hartwell St           2121.0
# 2      06     0601                             415 Summer St           2210.0
# 3       3     0301     INTERSECTION Lewis St & Commercial St              NaN
# 4       7     0706  INTERSECTION Woodward St & Dorchester St              NaN
#
#   latitude longitude                source
# 0  42.3606  -71.0638       City Worker App
# 1  42.3096  -71.0838      Constituent Call
# 2  42.3461  -71.0456          Self Service
# 3  42.3594  -71.0587  Citizens Connect App
# 4  42.3594  -71.0587      Constituent Call
#
# [5 rows x 29 columns]

# %%
violations311.neighborhood.value_counts()
# Out:
# Dorchester                                      32497
# South Boston / South Boston Waterfront          19409
# Roxbury                                         19283
# Allston / Brighton                              15801
# East Boston                                     15756
# South End                                       15396
# Downtown / Financial District                   13827
# Jamaica Plain                                   13118
# Back Bay                                        11330
# Greater Mattapan                                 8967
# Hyde Park                                        8350
# Roslindale                                       8128
# Boston                                           7987
# Charlestown                                      7775
# West Roxbury                                     7318
# Beacon Hill                                      7134
# Mission Hill                                     4647
# Fenway / Kenmore / Audubon Circle / Longwood     4521
# South Boston                                     2092
#                                                  1988
# Brighton                                         1208
# Allston                                           621
# Mattapan                                          439
# Chestnut Hill                                      26
# Name: neighborhood, dtype: int64

# %%
df = df[df["ontime"] == "OVERDUE"]

# %%
top_10_locations = list(df["location_street_name"].value_counts().keys())[:10]
top_10_locations_count = list(df["location_street_name"].value_counts().values)[:10]

# %%
print(top_10_locations)
print(top_10_locations_count)
# Out:
# ['INTERSECTION Boylston St & Park Dr', 'INTERSECTION Cambridge St & Charles St', '1 City Hall Plz', 'INTERSECTION Massachusetts Ave & Boylston St', 'INTERSECTION Cambridge St & Charlesbank Rd', 'INTERSECTION Freeport St & William T Morrissey Blvd', 'INTERSECTION Walk Hill St & American Legion Hwy', 'INTERSECTION Ukraine Way & Washington St', 'INTERSECTION Traveler St & W Broadway', 'INTERSECTION Congress St & Atlantic Ave']
# [56, 50, 46, 44, 43, 39, 37, 32, 31, 29]

# %%
df["reason"].value_counts()
# Out:
# Enforcement & Abandoned Vehicles     3978
# Street Cleaning                      2552
# Code Enforcement                     2402
# Sanitation                           1679
# Highway Maintenance                  1639
# Signs & Signals                       789
# Recycling                             779
# Housing                               567
# Trees                                 510
# Environmental Services                496
# Park Maintenance & Safety             412
# Building                              388
# Street Lights                         285
# Animal Issues                         282
# Graffiti                              254
# Abandoned Bicycle                     112
# Administrative & General Requests     110
# Health                                 82
# Needle Program                         61
# Noise Disturbance                      57
# Notification                           30
# Catchbasin                             27
# Traffic Management & Engineering       25
# Fire Hydrant                           20
# Sidewalk Cover / Manhole               19
# Operations                             19
# Employee & General Comments            18
# Pothole                                10
# Generic Noise Disturbance               6
# General Request                         5
# Weights and Measures                    4
# Programs                                4
# Parking Complaints                      3
# Air Pollution Control                   3
# Neighborhood Services Issues            1
# Boston Bikes                            1
# MBTA                                    1
# Name: reason, dtype: int64
