# %%
# Importing Libraries

import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.transforms import Affine2D
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# %%
# Installing some other required libraries

# !pip3 install plotly==5.11.0 -q
# !pip3 install wordcloud -q
# Out:
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: python3.10 -m pip install --upgrade pip
#
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: python3.10 -m pip install --upgrade pip

# %%
# Reading the Violation DataFrame

df = pd.read_csv('800a2663-1d6a-46e7-9356-bedb70f5332c.csv')

# %%
# Printing the head of the DataFrame

df.head()
# Out:
#            status_dttm status   code  value               description  \
# 0  2022-10-25 14:33:50   Open  105.1    NaN  Failure to Obtain Permit
# 1  2022-10-25 09:10:17   Open  102.8    NaN               Maintenance
# 2  2022-10-24 15:41:12   Open  102.8    NaN               Maintenance
# 3  2022-10-24 15:15:50   Open  105.1    NaN  Failure to Obtain Permit
# 4  2022-10-24 14:47:59   Open  907.8    NaN   Fire Protection Systems
#
#   violation_stno violation_sthigh violation_street violation_suffix  \
# 0            266              NaN        Princeton               ST
# 1             98              NaN     Mount Vernon               ST
# 2             96              NaN     Mount Vernon               ST
# 3             85              NaN             Como               RD
# 4             27              NaN              Nay               ST
#
#   violation_city  ... ward       contact_addr1 contact_addr2 contact_city  \
# ...

# %%
# Plotting a Bar Graph for the Number of Violations based on the Violation Suffix

fig = df1['violation_suffix'].value_counts().plot(kind='bar')
plt.ylabel("Count of the violation")
plt.xlabel("Violation suffix in Buildin Violation Dataset")
plt.savefig('Violation Count.png', dpi=600)

# %%
# Plotting a Line Graph for the Number of Violations based on the Violation Suffix

df['violation_suffix'].value_counts().plot()
# Out:
# <AxesSubplot: >

# %%
# Plotting a Word Cloud with the most occuring words in the desctiptions of Violation Suffix ST

df_st = df[df['violation_suffix'] == 'ST']['description']
df_st.dropna(inplace=True)
wordcloud = WordCloud().generate_from_text(' '.join(df_st))

plt.imshow(wordcloud)
plt.axis("off")
plt.title('ST Violation Code')
plt.show()
# Out:
# /var/folders/73/1kdzs7qn01v55rn5825j1cjr0000gn/T/ipykernel_9649/3579130017.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_st.dropna(inplace=True)

# %%
# Plotting a Word Cloud with the most occuring words in the desctiptions of Violation Suffix AVE

df_ave = df[df['violation_suffix'] == 'AVE']['description']
df_ave.dropna(inplace=True)
wordcloud = WordCloud().generate_from_text(' '.join(df_ave))

plt.imshow(wordcloud)
plt.axis("off")
plt.title('AVE Violation Code')
plt.show()
# Out:
# /var/folders/73/1kdzs7qn01v55rn5825j1cjr0000gn/T/ipykernel_9649/3421838710.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ave.dropna(inplace=True)

# %%
# Plotting a Word Cloud with the most occuring words in the desctiptions of Violation Suffix RD

df_rd = df[df['violation_suffix'] == 'RD']['description']
df_rd.dropna(inplace=True)
wordcloud = WordCloud().generate_from_text(' '.join(df_rd))

plt.imshow(wordcloud)
plt.axis("off")
plt.title('RD Violation Code')
plt.show()
# Out:
# /var/folders/73/1kdzs7qn01v55rn5825j1cjr0000gn/T/ipykernel_9649/2376150689.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rd.dropna(inplace=True)

# %%
from sklearn.preprocessing import LabelBinarizer
lb = LabelBinarizer()
y = lb.fit_transform(suffix[:2])

# %%
y
# Out:
# array([[1],
#        [0]])

# %%
# Importing Rentsmart Dataset

df = pd.read_csv('RentSmart.csv')

# %%
# Printing the different types of Violations

df['violation_type'].unique()
# Out:
# array(['Enforcement Violations', 'Housing Complaints',
#        'Sanitation Requests', 'Civic Maintenance Requests',
#        'Building Violations', 'Housing Violations'], dtype=object)

# %%
# Printing the number of violations for each type of violation

df['violation_type'].value_counts()
# Out:
# Enforcement Violations        207664
# Housing Complaints             54192
# Sanitation Requests            38894
# Civic Maintenance Requests      4969
# Building Violations             3287
# Housing Violations               670
# Name: violation_type, dtype: int64

# %%
# Plotting the Number of Violations for each type of Violation

df['violation_type'].value_counts().plot(kind='bar')
plt.savefig('Violation_Type.png', dpi = 300)

# %%
# Plotting a Word Cloud with the most occuring words in the violation type Enforcement Violations

df_rd = df[df['violation_type'] == 'Enforcement Violations']['description']
df_rd.dropna(inplace=True)
wordcloud = WordCloud().generate_from_text(' '.join(df_rd))

plt.imshow(wordcloud)
plt.axis("off")
plt.title('Enforcement Violations')
plt.show()
# Out:
# /var/folders/73/1kdzs7qn01v55rn5825j1cjr0000gn/T/ipykernel_58488/216535145.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rd.dropna(inplace=True)

# %%
# Plotting a Word Cloud with the most occuring words in the violation type Housing Complaints

df_rd = df[df['violation_type'] == 'Housing Complaints']['description']
df_rd.dropna(inplace=True)
wordcloud = WordCloud().generate_from_text(' '.join(df_rd))

plt.imshow(wordcloud)
plt.axis("off")
plt.title('Housing Complaints')
plt.show()
# Out:
# /var/folders/73/1kdzs7qn01v55rn5825j1cjr0000gn/T/ipykernel_58488/4290815979.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rd.dropna(inplace=True)

# %%
# Plotting a Word Cloud with the most occuring words in the violation type Sanitation Requests

df_rd = df[df['violation_type'] == 'Sanitation Requests']['description']
df_rd.dropna(inplace=True)
wordcloud = WordCloud().generate_from_text(' '.join(df_rd))

plt.imshow(wordcloud)
plt.axis("off")
plt.title('Sanitation Requests')
plt.show()
# Out:
# /var/folders/73/1kdzs7qn01v55rn5825j1cjr0000gn/T/ipykernel_58488/268278708.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rd.dropna(inplace=True)

# %%
# Plotting a Word Cloud with the most occuring words in the violation type Civic Maintenance Requests

df_rd = df[df['violation_type'] == 'Civic Maintenance Requests']['description']
df_rd.dropna(inplace=True)
wordcloud = WordCloud().generate_from_text(' '.join(df_rd))

plt.imshow(wordcloud)
plt.axis("off")
plt.title('Civic Maintenance Requests')
plt.show()
# Out:
# /var/folders/73/1kdzs7qn01v55rn5825j1cjr0000gn/T/ipykernel_58488/3907403481.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rd.dropna(inplace=True)

# %%
# Plotting a Word Cloud with the most occuring words in the violation type Building Violations

df_rd = df[df['violation_type'] == 'Building Violations']['description']
df_rd.dropna(inplace=True)
wordcloud = WordCloud().generate_from_text(' '.join(df_rd))

plt.imshow(wordcloud)
plt.axis("off")
plt.title('Building Violations')
plt.show()
# Out:
# /var/folders/73/1kdzs7qn01v55rn5825j1cjr0000gn/T/ipykernel_58488/2435004954.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rd.dropna(inplace=True)

# %%
# Plotting a Word Cloud with the most occuring words in the violation type Housing Violations

df_rd = df[df['violation_type'] == 'Housing Violations']['description']
df_rd.dropna(inplace=True)
wordcloud = WordCloud().generate_from_text(' '.join(df_rd))

plt.imshow(wordcloud)
plt.axis("off")
plt.title('Housing Violations')
plt.show()
# Out:
# /var/folders/73/1kdzs7qn01v55rn5825j1cjr0000gn/T/ipykernel_58488/3057798274.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rd.dropna(inplace=True)

# %%
# Find relation between age and violation (Make graph of number of violation based on the buildings age)
# If remodelling effects ?
# Relation between property type
#In rent smart there are only 3287 entries for building violation and in Building violation dataset there are 21470 entries. So it's difficult to map
